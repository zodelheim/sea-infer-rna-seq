# %%
import anndata as ad
import matplotlib.pyplot as plt
import numpy as np
import scanpy as sc
from pathlib import Path
from gtfparse import read_gtf
import pandas as pd

# %%
fdir_raw = Path("/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/raw/")

# %%
data_raw = pd.read_csv(fdir_raw / 'Geuvadis.all.csv', index_col=0).T
data_raw = data_raw.astype(np.float32)
data_raw.head()
# Out:
#            ENST00000378604.3  ENST00000307786.8  ENST00000482402.1  \
# ERR188021           0.000000           0.000000           0.000000
# ERR188022           0.000000           0.000000           0.000000
# ERR188023           0.000000           0.169178           0.114391
# ERR188024           0.000000           0.000000           0.000000
# ERR188025           0.000000           0.107439           0.017849
# ...                      ...                ...                ...
# ERR204940           6.127458           0.000000           4.660298
# ERR205020           0.134626           0.000000           0.000000
# ERR205021           0.009035           0.000000           0.152969
# ERR205022           0.031064           0.000000           0.192926
# ERR205023           0.000000           0.000000           0.000000
#
#            ENST00000462293.1  ENST00000378602.3  ENST00000310991.8  \
# ERR188021                0.0           0.000000                0.0
# ERR188022                0.0           0.000000                0.0
# ERR188023                0.0           0.000000                0.0
# ERR188024                0.0           0.000000                0.0
# ERR188025                0.0           0.000000                0.0
# ...                      ...                ...                ...
# ERR204940                0.0           4.823868                0.0
# ERR205020                0.0           0.152967                0.0
# ERR205021                0.0           0.000000                0.0
# ERR205022                0.0           0.000000                0.0
# ERR205023                0.0           0.525239                0.0
#
#            ENST00000378598.4  ENST00000470931.2  ENST00000602604.1  \
# ERR188021                0.0                0.0           0.000000
# ERR188022                0.0                0.0           0.000000
# ERR188023                0.0                0.0           0.000000
# ERR188024                0.0                0.0           0.219131
# ERR188025                0.0                0.0           0.000000
# ...                      ...                ...                ...
# ERR204940                0.0                0.0           0.000000
# ERR205020                0.0                0.0           0.000000
# ERR205021                0.0                0.0           0.000000
# ERR205022                0.0                0.0           0.000000
# ERR205023                0.0                0.0           0.000000
#
#            ENST00000416272.1  ...  ENST00000426199.1  ENST00000517139.1  \
# ERR188021                0.0  ...                0.0                0.0
# ERR188022                0.0  ...                0.0                0.0
# ERR188023                0.0  ...                0.0                0.0
# ERR188024                0.0  ...                0.0                0.0
# ERR188025                0.0  ...                0.0                0.0
# ...                      ...  ...                ...                ...
# ERR204940                0.0  ...                0.0                0.0
# ERR205020                0.0  ...                0.0                0.0
# ERR205021                0.0  ...                0.0                0.0
# ERR205022                0.0  ...                0.0                0.0
# ERR205023                0.0  ...                0.0                0.0
#
#            MSTRG.36845.1  ENST00000619329.1  ENST00000258589.8  \
# ERR188021            0.0           0.000000           0.000000
# ERR188022            0.0           0.000000           0.000000
# ERR188023            0.0           0.000000           0.014311
# ERR188024            0.0           0.000000           0.000000
# ERR188025            0.0           0.000000           0.000000
# ...                  ...                ...                ...
# ERR204940            0.0           0.000000           0.180813
# ERR205020            0.0           0.769428           0.000000
# ERR205021            0.0           0.000000           0.000000
# ERR205022            0.0           0.000000           0.000000
# ERR205023            0.0           0.000000           0.000000
#
#            ENST00000420810.1  ENST00000431853.1  ENST00000711259.1  \
# ERR188021                0.0           0.000000           0.000000
# ERR188022                0.0           0.000000           0.000000
# ERR188023                0.0           0.000000           0.000000
# ERR188024                0.0           0.000000           0.000000
# ERR188025                0.0           0.000000           0.000000
# ...                      ...                ...                ...
# ERR204940                0.0          59.465179           2.708632
# ERR205020                0.0           0.000000           0.000000
# ERR205021                0.0           0.000000           0.000000
# ERR205022                0.0           0.000000           0.000000
# ERR205023                0.0           0.000000           0.000000
#
#            ENST00000711266.1  ENST00000711267.1
# ERR188021           0.000000           0.000000
# ERR188022           0.000000           0.074617
# ERR188023           0.000000           0.000000
# ERR188024           0.000000           0.000000
# ERR188025           0.000000           0.000000
# ...                      ...                ...
# ERR204940           3.095435           9.169821
# ERR205020           0.000000           0.000000
# ERR205021           0.000000           0.000000
# ERR205022           0.000000           0.000000
# ERR205023           0.000000           0.000000
#
# [667 rows x 338725 columns]

# %%
data_header = pd.read_csv(fdir_raw / 'Geuvadis.SraRunTable.txt', index_col=0)
data_header.head()
# Out:
#           Assay Type  AvgSpotLen       Bases BioProject     BioSample  \
# Run
# ERR188021    RNA-Seq         150  4876174200  PRJEB3366  SAMEA1573446
# ERR188022    RNA-Seq         150  3348579900  PRJEB3366  SAMEA1573207
# ERR188023    RNA-Seq         152  5548298680  PRJEB3366  SAMEA1573500
# ERR188024    RNA-Seq         150  3572181450  PRJEB3366  SAMEA1573203
# ERR188025    RNA-Seq         152  5348693800  PRJEB3366  SAMEA1573346
# ...              ...         ...         ...        ...           ...
# ERR205019    RNA-Seq         150  2170416900  PRJEB3366  SAMEA1573209
# ERR205020    RNA-Seq         150  2607598050  PRJEB3366  SAMEA1573157
# ERR205021    RNA-Seq         150  2623394250  PRJEB3366  SAMEA1573421
# ERR205022    RNA-Seq         150  3289196100  PRJEB3366  SAMEA1573433
# ERR205023    RNA-Seq         150  2501212800  PRJEB3366  SAMEA1573450
#
#             Broker_name       Bytes Center Name common_name Consent  ...  \
# Run                                                                  ...
# ERR188021  ArrayExpress  3559612733       UNIGE       human  public  ...
# ERR188022  ArrayExpress  2387687573       UNIGE       human  public  ...
# ERR188023  ArrayExpress  3922060114         CRG       human  public  ...
# ERR188024  ArrayExpress  2494830964       UNIGE       human  public  ...
# ERR188025  ArrayExpress  3609467912         CRG       human  public  ...
# ...                 ...         ...         ...         ...     ...  ...
# ERR205019  ArrayExpress  1464689825       UNIGE       human  public  ...
# ERR205020  ArrayExpress  1713213648       UNIGE       human  public  ...
# ERR205021  ArrayExpress  1765067265       UNIGE       human  public  ...
# ERR205022  ArrayExpress  2168043784       UNIGE       human  public  ...
# ERR205023  ArrayExpress  1651577535       UNIGE       human  public  ...
#
#                     ReleaseDate           create_date version   Sample Name  \
# Run
# ERR188021  2012-11-07T00:00:00Z  2021-10-17T23:14:00Z       2  SAMEA1573446
# ERR188022  2012-11-07T00:00:00Z  2022-07-21T01:31:00Z       2  SAMEA1573207
# ERR188023  2012-11-07T00:00:00Z  2021-10-17T23:19:00Z       2  SAMEA1573500
# ERR188024  2012-11-07T00:00:00Z  2021-10-17T22:59:00Z       2  SAMEA1573203
# ERR188025  2012-11-07T00:00:00Z  2022-07-22T21:12:00Z       2  SAMEA1573346
# ...                         ...                   ...     ...           ...
# ERR205019  2012-12-05T00:00:00Z  2022-07-13T19:28:00Z       2  SAMEA1573209
# ERR205020  2013-02-21T00:00:00Z  2022-07-22T21:01:00Z       2  SAMEA1573157
# ERR205021  2013-02-21T00:00:00Z  2022-07-16T21:05:00Z       2  SAMEA1573421
# ERR205022  2012-12-05T00:00:00Z  2021-10-19T02:59:00Z       2  SAMEA1573433
# ERR205023  2012-12-05T00:00:00Z  2022-07-22T21:03:00Z       2  SAMEA1573450
#
#             Sample_name  SRA Study                    strain  Submitter_Id  \
# Run
# ERR188021  GEUV:NA20508  ERP001942  lymphoblastoid cell line  GEUV:NA20508
# ERR188022  GEUV:NA12812  ERP001942  lymphoblastoid cell line  GEUV:NA12812
# ERR188023  GEUV:HG00315  ERP001942  lymphoblastoid cell line  GEUV:HG00315
# ERR188024  GEUV:NA12749  ERP001942  lymphoblastoid cell line  GEUV:NA12749
# ERR188025  GEUV:HG00377  ERP001942  lymphoblastoid cell line  GEUV:HG00377
# ...                 ...        ...                       ...           ...
# ERR205019  GEUV:NA18502  ERP001942  lymphoblastoid cell line  GEUV:NA18502
# ERR205020  GEUV:NA19198  ERP001942  lymphoblastoid cell line  GEUV:NA19198
# ERR205021  GEUV:NA19210  ERP001942  lymphoblastoid cell line  GEUV:NA19210
# ERR205022  GEUV:NA12156  ERP001942  lymphoblastoid cell line  GEUV:NA12156
# ERR205023  GEUV:NA11843  ERP001942  lymphoblastoid cell line  GEUV:NA11843
#
#               Sample Sex
# Run
# ERR188021  ERR188021   F
# ERR188022  ERR188022   M
# ERR188023  ERR188023   F
# ERR188024  ERR188024   F
# ERR188025  ERR188025   F
# ...              ...  ..
# ERR205019  ERR205019   F
# ERR205020  ERR205020   M
# ERR205021  ERR205021   M
# ERR205022  ERR205022   F
# ERR205023  ERR205023   M
#
# [667 rows x 44 columns]

# %%
gtf_rawdata = read_gtf(fdir_raw / 'all_transcripts_strigtie_merged.gtf')
gtf_data = gtf_rawdata.to_pandas()

gtf_data.head()
# gtf_data = gtf_data[['seqname', 'transcript_id']]

# %%
gtf_data.loc[data_raw.columns, ['gene_id', 'seqname', 'source', 'gene_name']]
# Out:
#                               gene_id seqname  source gene_name
# ENST00000378604.3  ENSG00000169885.10    chr1  HAVANA    CALML6
# ENST00000378604.3  ENSG00000169885.10    chr1  HAVANA    CALML6
# ENST00000378604.3  ENSG00000169885.10    chr1  HAVANA    CALML6
# ENST00000378604.3  ENSG00000169885.10    chr1  HAVANA    CALML6
# ENST00000378604.3  ENSG00000169885.10    chr1  HAVANA    CALML6
# ...                               ...     ...     ...       ...
# ENST00000711259.1   ENSG00000292365.1    chrY  HAVANA    DPH3P2
# ENST00000711266.1   ENSG00000292367.1    chrY  HAVANA   ELOCP24
# ENST00000711266.1   ENSG00000292367.1    chrY  HAVANA   ELOCP24
# ENST00000711267.1   ENSG00000292368.1    chrY  HAVANA   TRPC6P1
# ENST00000711267.1   ENSG00000292368.1    chrY  HAVANA   TRPC6P1
#
# [3097066 rows x 4 columns]

# %%
# gtf_data.reset_index()

gtf_data['transcript_id'] = gtf_data.index
gtf_data = gtf_data.loc[data_raw.columns, ['gene_id', 'seqname', 'source', 'gene_name', 'transcript_id']].drop_duplicates("transcript_id")

# %%
gtf_data
# Out:
#                               gene_id seqname     source gene_name  \
# ENST00000378604.3  ENSG00000169885.10    chr1     HAVANA    CALML6
# ENST00000307786.8  ENSG00000169885.10    chr1     HAVANA    CALML6
# ENST00000482402.1  ENSG00000169885.10    chr1     HAVANA    CALML6
# ENST00000462293.1  ENSG00000169885.10    chr1     HAVANA    CALML6
# ENST00000378602.3  ENSG00000178821.13    chr1     HAVANA    TMEM52
# ...                               ...     ...        ...       ...
# ENST00000420810.1         MSTRG.36847    chrY  StringTie   CYCSP49
# ENST00000431853.1         MSTRG.36848    chrY  StringTie   CTBP2P1
# ENST00000711259.1   ENSG00000292365.1    chrY     HAVANA    DPH3P2
# ENST00000711266.1   ENSG00000292367.1    chrY     HAVANA   ELOCP24
# ENST00000711267.1   ENSG00000292368.1    chrY     HAVANA   TRPC6P1
#
#                        transcript_id
# ENST00000378604.3  ENST00000378604.3
# ENST00000307786.8  ENST00000307786.8
# ENST00000482402.1  ENST00000482402.1
# ENST00000462293.1  ENST00000462293.1
# ENST00000378602.3  ENST00000378602.3
# ...                              ...
# ENST00000420810.1  ENST00000420810.1
# ENST00000431853.1  ENST00000431853.1
# ENST00000711259.1  ENST00000711259.1
# ENST00000711266.1  ENST00000711266.1
# ENST00000711267.1  ENST00000711267.1
#
# [338725 rows x 5 columns]

# %%
data_header
# Out:
#           Assay Type  AvgSpotLen       Bases BioProject     BioSample  \
# Run
# ERR188021    RNA-Seq         150  4876174200  PRJEB3366  SAMEA1573446
# ERR188022    RNA-Seq         150  3348579900  PRJEB3366  SAMEA1573207
# ERR188023    RNA-Seq         152  5548298680  PRJEB3366  SAMEA1573500
# ERR188024    RNA-Seq         150  3572181450  PRJEB3366  SAMEA1573203
# ERR188025    RNA-Seq         152  5348693800  PRJEB3366  SAMEA1573346
# ...              ...         ...         ...        ...           ...
# ERR205019    RNA-Seq         150  2170416900  PRJEB3366  SAMEA1573209
# ERR205020    RNA-Seq         150  2607598050  PRJEB3366  SAMEA1573157
# ERR205021    RNA-Seq         150  2623394250  PRJEB3366  SAMEA1573421
# ERR205022    RNA-Seq         150  3289196100  PRJEB3366  SAMEA1573433
# ERR205023    RNA-Seq         150  2501212800  PRJEB3366  SAMEA1573450
#
#             Broker_name       Bytes Center Name common_name Consent  ...  \
# Run                                                                  ...
# ERR188021  ArrayExpress  3559612733       UNIGE       human  public  ...
# ERR188022  ArrayExpress  2387687573       UNIGE       human  public  ...
# ERR188023  ArrayExpress  3922060114         CRG       human  public  ...
# ERR188024  ArrayExpress  2494830964       UNIGE       human  public  ...
# ERR188025  ArrayExpress  3609467912         CRG       human  public  ...
# ...                 ...         ...         ...         ...     ...  ...
# ERR205019  ArrayExpress  1464689825       UNIGE       human  public  ...
# ERR205020  ArrayExpress  1713213648       UNIGE       human  public  ...
# ERR205021  ArrayExpress  1765067265       UNIGE       human  public  ...
# ERR205022  ArrayExpress  2168043784       UNIGE       human  public  ...
# ERR205023  ArrayExpress  1651577535       UNIGE       human  public  ...
#
#                     ReleaseDate           create_date version   Sample Name  \
# Run
# ERR188021  2012-11-07T00:00:00Z  2021-10-17T23:14:00Z       2  SAMEA1573446
# ERR188022  2012-11-07T00:00:00Z  2022-07-21T01:31:00Z       2  SAMEA1573207
# ERR188023  2012-11-07T00:00:00Z  2021-10-17T23:19:00Z       2  SAMEA1573500
# ERR188024  2012-11-07T00:00:00Z  2021-10-17T22:59:00Z       2  SAMEA1573203
# ERR188025  2012-11-07T00:00:00Z  2022-07-22T21:12:00Z       2  SAMEA1573346
# ...                         ...                   ...     ...           ...
# ERR205019  2012-12-05T00:00:00Z  2022-07-13T19:28:00Z       2  SAMEA1573209
# ERR205020  2013-02-21T00:00:00Z  2022-07-22T21:01:00Z       2  SAMEA1573157
# ERR205021  2013-02-21T00:00:00Z  2022-07-16T21:05:00Z       2  SAMEA1573421
# ERR205022  2012-12-05T00:00:00Z  2021-10-19T02:59:00Z       2  SAMEA1573433
# ERR205023  2012-12-05T00:00:00Z  2022-07-22T21:03:00Z       2  SAMEA1573450
#
#             Sample_name  SRA Study                    strain  Submitter_Id  \
# Run
# ERR188021  GEUV:NA20508  ERP001942  lymphoblastoid cell line  GEUV:NA20508
# ERR188022  GEUV:NA12812  ERP001942  lymphoblastoid cell line  GEUV:NA12812
# ERR188023  GEUV:HG00315  ERP001942  lymphoblastoid cell line  GEUV:HG00315
# ERR188024  GEUV:NA12749  ERP001942  lymphoblastoid cell line  GEUV:NA12749
# ERR188025  GEUV:HG00377  ERP001942  lymphoblastoid cell line  GEUV:HG00377
# ...                 ...        ...                       ...           ...
# ERR205019  GEUV:NA18502  ERP001942  lymphoblastoid cell line  GEUV:NA18502
# ERR205020  GEUV:NA19198  ERP001942  lymphoblastoid cell line  GEUV:NA19198
# ERR205021  GEUV:NA19210  ERP001942  lymphoblastoid cell line  GEUV:NA19210
# ERR205022  GEUV:NA12156  ERP001942  lymphoblastoid cell line  GEUV:NA12156
# ERR205023  GEUV:NA11843  ERP001942  lymphoblastoid cell line  GEUV:NA11843
#
#               Sample Sex
# Run
# ERR188021  ERR188021   F
# ERR188022  ERR188022   M
# ERR188023  ERR188023   F
# ERR188024  ERR188024   F
# ERR188025  ERR188025   F
# ...              ...  ..
# ERR205019  ERR205019   F
# ERR205020  ERR205020   M
# ERR205021  ERR205021   M
# ERR205022  ERR205022   F
# ERR205023  ERR205023   M
#
# [667 rows x 44 columns]

# %%
adata = ad.AnnData(data_raw)
adata.var = gtf_data
adata.obs = data_header
adata.write_h5ad('/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/raw/geuvadis.h5ad')

# %%
adata = ad.read_h5ad('/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/raw/geuvadis.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 667 × 338725
#     obs: 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample', 'Broker_name', 'Bytes', 'Center Name', 'common_name', 'Consent', 'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region', 'ENA-FIRST-PUBLIC (run)', 'ena_first_public', 'ENA-LAST-UPDATE (run)', 'ENA_last_update', 'Experiment', 'Experimental_Factor:_laboratory (exp)', 'Experimental_Factor:_population (exp)', 'external_id', 'INSDC_center_alias', 'INSDC_center_name', 'INSDC_first_public', 'INSDC_last_update', 'INSDC_status', 'Instrument', 'Library Name', 'LibraryLayout', 'LibrarySelection', 'LibrarySource', 'Organism', 'Platform', 'population', 'ReleaseDate', 'create_date', 'version', 'Sample Name', 'Sample_name', 'SRA Study', 'strain', 'Submitter_Id', 'Sample', 'Sex'
#     var: 'gene_id', 'seqname', 'source', 'gene_name', 'transcript_id'

# %%
subdata = adata[adata.obs['Sex'] == 'F', 
                adata.var['seqname'] == 'chrY']

subdata
# Out:
# View of AnnData object with n_obs × n_vars = 338 × 1009
#     obs: 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample', 'Broker_name', 'Bytes', 'Center Name', 'common_name', 'Consent', 'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region', 'ENA-FIRST-PUBLIC (run)', 'ena_first_public', 'ENA-LAST-UPDATE (run)', 'ENA_last_update', 'Experiment', 'Experimental_Factor:_laboratory (exp)', 'Experimental_Factor:_population (exp)', 'external_id', 'INSDC_center_alias', 'INSDC_center_name', 'INSDC_first_public', 'INSDC_last_update', 'INSDC_status', 'Instrument', 'Library Name', 'LibraryLayout', 'LibrarySelection', 'LibrarySource', 'Organism', 'Platform', 'population', 'ReleaseDate', 'create_date', 'version', 'Sample Name', 'Sample_name', 'SRA Study', 'strain', 'Submitter_Id', 'Sample', 'Sex'
#     var: 'gene_id', 'seqname', 'source', 'gene_name', 'transcript_id'

# %%
subdata.obs
# Out:
#           Assay Type  AvgSpotLen       Bases BioProject     BioSample  \
# Run
# ERR188021    RNA-Seq         150  4876174200  PRJEB3366  SAMEA1573446
# ERR188023    RNA-Seq         152  5548298680  PRJEB3366  SAMEA1573500
# ERR188024    RNA-Seq         150  3572181450  PRJEB3366  SAMEA1573203
# ERR188025    RNA-Seq         152  5348693800  PRJEB3366  SAMEA1573346
# ERR188027    RNA-Seq         150  4337546250  PRJEB3366  SAMEA1573516
# ...              ...         ...         ...        ...           ...
# ERR205014    RNA-Seq         150  1818419850  PRJEB3366  SAMEA1573131
# ERR205016    RNA-Seq         150  7105388850  PRJEB3366  SAMEA1573245
# ERR205017    RNA-Seq         150  2398452600  PRJEB3366  SAMEA1573532
# ERR205019    RNA-Seq         150  2170416900  PRJEB3366  SAMEA1573209
# ERR205022    RNA-Seq         150  3289196100  PRJEB3366  SAMEA1573433
#
#             Broker_name       Bytes Center Name common_name Consent  ...  \
# Run                                                                  ...
# ERR188021  ArrayExpress  3559612733       UNIGE       human  public  ...
# ERR188023  ArrayExpress  3922060114         CRG       human  public  ...
# ERR188024  ArrayExpress  2494830964       UNIGE       human  public  ...
# ERR188025  ArrayExpress  3609467912         CRG       human  public  ...
# ERR188027  ArrayExpress  3157358383       UNIGE       human  public  ...
# ...                 ...         ...         ...         ...     ...  ...
# ERR205014  ArrayExpress  1200301333       UNIGE       human  public  ...
# ERR205016  ArrayExpress  4872768003        ICMB       human  public  ...
# ERR205017  ArrayExpress  1602770635       UNIGE       human  public  ...
# ERR205019  ArrayExpress  1464689825       UNIGE       human  public  ...
# ERR205022  ArrayExpress  2168043784       UNIGE       human  public  ...
#
#                     ReleaseDate           create_date version   Sample Name  \
# Run
# ERR188021  2012-11-07T00:00:00Z  2021-10-17T23:14:00Z       2  SAMEA1573446
# ERR188023  2012-11-07T00:00:00Z  2021-10-17T23:19:00Z       2  SAMEA1573500
# ERR188024  2012-11-07T00:00:00Z  2021-10-17T22:59:00Z       2  SAMEA1573203
# ERR188025  2012-11-07T00:00:00Z  2022-07-22T21:12:00Z       2  SAMEA1573346
# ERR188027  2012-11-07T00:00:00Z  2021-10-17T23:08:00Z       2  SAMEA1573516
# ...                         ...                   ...     ...           ...
# ERR205014  2012-12-05T00:00:00Z  2021-10-19T02:49:00Z       2  SAMEA1573131
# ERR205016  2012-12-05T00:00:00Z  2021-10-19T03:25:00Z       2  SAMEA1573245
# ERR205017  2012-12-05T00:00:00Z  2021-10-19T02:40:00Z       2  SAMEA1573532
# ERR205019  2012-12-05T00:00:00Z  2022-07-13T19:28:00Z       2  SAMEA1573209
# ERR205022  2012-12-05T00:00:00Z  2021-10-19T02:59:00Z       2  SAMEA1573433
#
#             Sample_name  SRA Study                    strain  Submitter_Id  \
# Run
# ERR188021  GEUV:NA20508  ERP001942  lymphoblastoid cell line  GEUV:NA20508
# ERR188023  GEUV:HG00315  ERP001942  lymphoblastoid cell line  GEUV:HG00315
# ERR188024  GEUV:NA12749  ERP001942  lymphoblastoid cell line  GEUV:NA12749
# ERR188025  GEUV:HG00377  ERP001942  lymphoblastoid cell line  GEUV:HG00377
# ERR188027  GEUV:NA07056  ERP001942  lymphoblastoid cell line  GEUV:NA07056
# ...                 ...        ...                       ...           ...
# ERR205014  GEUV:NA07346  ERP001942  lymphoblastoid cell line  GEUV:NA07346
# ERR205016  GEUV:HG00237  ERP001942  lymphoblastoid cell line  GEUV:HG00237
# ERR205017  GEUV:NA18870  ERP001942  lymphoblastoid cell line  GEUV:NA18870
# ERR205019  GEUV:NA18502  ERP001942  lymphoblastoid cell line  GEUV:NA18502
# ERR205022  GEUV:NA12156  ERP001942  lymphoblastoid cell line  GEUV:NA12156
#
#               Sample Sex
# Run
# ERR188021  ERR188021   F
# ERR188023  ERR188023   F
# ERR188024  ERR188024   F
# ERR188025  ERR188025   F
# ERR188027  ERR188027   F
# ...              ...  ..
# ERR205014  ERR205014   F
# ERR205016  ERR205016   F
# ERR205017  ERR205017   F
# ERR205019  ERR205019   F
# ERR205022  ERR205022   F
#
# [338 rows x 44 columns]

# %%
sc.pl.matrixplot(
    subdata, 
    groupby='Sex',
    var_names=subdata.var_names
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[216], line 1
# ----> 1 sc.pl.matrixplot(
#       2     subdata,
#       3     # groupby='Sex',
#       4     var_names=subdata.var_names
#       5 )
#
# File ~/Documents/PYTHON/RNASeqAnalysis/.venv/lib/python3.10/site-packages/legacy_api_wrap/__init__.py:80, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#      77 @wraps(fn)
#      78 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#      79     if len(args_all) <= n_positional:
# ---> 80         return fn(*args_all, **kw)
#      82     args_pos: P.args
#      83     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
# TypeError: matrixplot() missing 1 required positional argument: 'groupby'
