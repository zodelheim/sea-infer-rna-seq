# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
fdir_raw = Path("/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/raw/")
fdir_processed = Path("/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/interim")
fdir_traintest = Path("/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/processed") / 'sex'
fdir_external = Path("/home/ar3/Documents/PYTHON/RNASeqAnalysis/data/external")

# %%
data_raw = pd.read_csv(fdir_raw / 'Geuvadis.all.csv', index_col=0).T
data_raw = data_raw.astype(np.float32)

# %%
sex = 'chrXY'
# sex = 'chrX'
# sex = 'chrY'
# sex = 'autosome'

# %%
# features = pd.read_csv(fdir_processed / f'feature_importance.{"xgboost"}.{sex}.csv', index_col=0).index
# print(f"{features.shape=}")

# %%
data = pd.read_csv(fdir_traintest / f'geuvadis.preprocessed.{sex}.csv', index_col=0)

# %%
data_header = pd.read_csv(fdir_raw / 'Geuvadis.SraRunTable.txt', index_col=0)
data_header = data_header[[
    'Sex',
]]
data_header = data_header.loc[data.index]
data_header
# Out:
#           Sex
# ERR188021   F
# ERR188022   M
# ERR188023   F
# ERR188024   F
# ERR188025   F
# ...        ..
# ERR204940   F
# ERR205020   M
# ERR205021   M
# ERR205022   F
# ERR205023   M
#
# [667 rows x 1 columns]

# %%
data['Sex'] = data_header['Sex']
data_raw["Sex"] = data_header['Sex']

# %%
transcripts_x = pd.read_csv(fdir_processed / "all_transcripts.chrX.csv", index_col=0).values.ravel()
transcripts_y = pd.read_csv(fdir_processed / "all_transcripts.chrY.csv", index_col=0).values.ravel()

print(f"{transcripts_x.shape=}")
print(f"{transcripts_y.shape=}")

intersection_x = data.columns.intersection(transcripts_x)
intersection_y = data.columns.intersection(transcripts_y)

intersection_x_raw = data_raw.columns.intersection(transcripts_x)
intersection_y_raw = data_raw.columns.intersection(transcripts_y)

print(f"{intersection_x_raw.shape=}")
print(f"{intersection_y_raw.shape=}")
print(f"{intersection_x.shape=}")
print(f"{intersection_y.shape=}")
# Out:
# transcripts_x.shape=(11741,)
# transcripts_y.shape=(1428,)
# intersection_x_raw.shape=(10602,)
# intersection_y_raw.shape=(1009,)
# intersection_x.shape=(95,)
# intersection_y.shape=(6,)

# %%
# plt.figure()
# sns.histplot(data_raw.loc[data_raw['Sex'] == 'M', intersection_y_raw].mean())
# sns.histplot(data_raw.loc[data_raw['Sex'] == 'F', intersection_y_raw].mean())
# plt.show()

result = data_raw.loc[data_raw['Sex'] == 'M', intersection_y_raw].mean() - data_raw.loc[data_raw['Sex'] == 'F', intersection_y_raw].mean()
result = result.abs().sort_values(ascending=False)
# plt.bar(x=range(len(result.index)), height=result.values, logscale=True)
# sns.barplot(result)
result
# Out:
# ENST00000250784.13    8.175044e+01
# ENST00000361365.7     6.756042e+01
# MSTRG.36785.9         2.959292e+01
# MSTRG.36713.16        2.655986e+01
# ENST00000336079.8     1.801280e+01
#                           ...
# ENST00000418188.1     1.155991e-05
# ENST00000413372.1     9.208918e-06
# ENST00000458209.1     4.939735e-06
# ENST00000435012.1     2.437690e-06
# ENST00000454054.5     6.079027e-08
# Length: 1009, dtype: float32

# %%
# Out:
# Index(['ENST00000155093.8', 'ENST00000215473.7', 'ENST00000250784.13',
#        'ENST00000250823.5', 'ENST00000250825.5', 'ENST00000250838.6',
#        'ENST00000253320.8', 'ENST00000258589.8', 'ENST00000284856.4',
#        'ENST00000304790.3',
#        ...
#        'MSTRG.36853.25', 'MSTRG.36853.26', 'MSTRG.36853.27', 'MSTRG.36853.29',
#        'MSTRG.36853.3', 'MSTRG.36853.4', 'MSTRG.36853.5', 'MSTRG.36853.6',
#        'MSTRG.36853.9', 'Sex'],
#       dtype='object', length=1010)
